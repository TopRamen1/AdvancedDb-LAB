# %%
from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy import create_engine
from sqlalchemy import select

# %%
db_string = "mysql+pymysql://bauer1:W0JjW9jge2SYwwYh@mysql.agh.edu.pl:3306/bauer1"

db = create_engine(db_string)

# %%
def show_table_info(table_name):
    metadata = MetaData()
    table = Table(table_name, metadata , autoload=True, autoload_with=db)
    # print(repr(table))
    print("Info about table: {}".format(table_name))
    print(table.columns.keys())
    print('\n')

# %%
show_table_info('customers')
show_table_info('employees')
show_table_info('orderd')
show_table_info('payments')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~/anaconda3/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     843         try:
# --> 844             raise err
#     845         finally:
#
# ~/anaconda3/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     831                 sock.bind(source_address)
# --> 832             sock.connect(sa)
#     833             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
